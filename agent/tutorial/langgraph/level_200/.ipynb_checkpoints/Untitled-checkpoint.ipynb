# %%
# !ls
# Out:
# Untitled.ipynb chain

# %%
# %load_ext autoreload
# %autoreload 2

from chain import (
    NoticeEmailExtract
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 4
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 4 from chain import (
#       5     NoticeEmailExtract
#       6 )
#
# ImportError: cannot import name 'NoticeEmailExtract' from 'chain' (unknown location)
